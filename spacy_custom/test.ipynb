# %%
import spacy

# %%
nlp = spacy.load("./output/model-best")

# %%
phrase = "Je vais à Paris depuis Lyon demain"
doc = nlp(phrase)

for ent in doc.ents:
    print(f"{ent.text} - {ent.label_}")
# Out:
# Paris - VILLE_ARRIVEE
# Lyon - VILLE_ORIGINE
